# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Heart.csv')

# %%
df

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.dtypes

# %%
(df == 0).sum()

# %%
df['Age'].mean()

# %%
subset = df[df['Age'] > 50]
subset.head()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['Age' , 'Sex' , 'ChestPain']]
y = df[['RestBP' , 'Chol']]

# %%
x_train , y_train , x_test , y_test = train_test_split(x , y , test_size = 0.25 , random_state = 1)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test
